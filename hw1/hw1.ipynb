# %% [markdown]
# ### Perform horizontal flipping on sample1.png and output the result as result1.png.
# https://pinetools.com/flip-image

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('hw1_sample_images\sample1.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.title('sample1.png')
plt.show()

# %%
height, width, channel = img.shape

# %%
# swap by column
for j in range(width//2):
    img[:, [j, width-j-1]] = img[:, [width-j-1, j]]

# %%
plt.imshow(img)
plt.title('sample1.png')
plt.show()

img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
cv2.imwrite("result1.png",img)
# Out:
# True

# %% [markdown]
# ### Please convert result1 to a grayscale image named result2.png.
# https://cg2010studio.com/2011/06/06/opencv-%E8%BD%89%E6%8F%9B%E5%BD%B1%E5%83%8F%E7%82%BA%E7%81%B0%E9%9A%8E-transform-image-to-gray-level/

# %%
gray = (img[:,:,0]+img[:,:,1]+img[:,:,2])/3
plt.imshow(gray, cmap='gray')

# %%
gray = 0.299*img[:,:,0]+0.587*img[:,:,1]+0.114*img[:,:,2]
plt.imshow(gray, cmap='gray')

img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
cv2.imwrite("result2.png",img)
# Out:
# True

# %% [markdown]
# ### Decrease the brightness of sample2 by dividing the intensity values by 2 and output the result as result3.png.

# %%
img = cv2.imread('hw1_sample_images\sample2.png', cv2.IMREAD_GRAYSCALE)
plt.imshow(img, cmap='gray')

# %%
img2 = img
img3 = img

# %%
img2 = img2/2 
img2 = np.around(img2)
plt.imshow(img2, cmap='gray')

# %% [markdown]
# ### Increase the brightness of result3 by multiplying the intensity values by 3 and output the result asresult4.png.

# %%
img3 = img3*3.0 
img3 = np.around(img3)
img3 = np.clip(img3,0,255)
plt.imshow(img3, cmap='gray')

# %% [markdown]
# ### Plot the histograms of sample2, result3 and result4. What can you observe from these three his-tograms?

# %%
hist,bins = np.histogram(img,bins=256,range=(0,256))
print(img)
print(hist)
print(bins)
# Out:
# [[ 91  91  92 ...  57  57  57]
#  [ 91  91  92 ...  57  57  57]
#  [ 92  92  92 ...  57  57  57]
#  ...
#  [ 46  45  45 ... 148 147 147]
#  [ 40  43  48 ... 146 146 145]
#  [ 45  46  53 ... 145 145 145]]
# [  11   38  204 1370  958  631  542  720 1115 1221  962  849  823  736
#   666  624  628  567  593  552  575  556  590  567  563  595  613  623
#   545  585  651  600  611  628  608  638  609  664  601  657  644  658
#   685  657  741  775  800  841  834  796  806  788  714  708 1337 3490
#  4708 6134 6307 5752 5196 6432 5979 6659 5452 6108 5255 5485 5326 4969
#  4379 4965 4853 5197 4435 4487 4831 5069 4868 4611 4699 4604 4434 4649
#  4729 4717 5149 4942 4990 4735 4543 4488 4418 4340 4283 4394 4590 5255
#  5149 4427 4135 4056 3774 3801 3553 3242 3465 3003 2791 2653 2725 2866
#  2913 2662 2354 2615 2577 2273 2009 2231 2176 2312 2107 2029 1811 1690
#  1626 1439 1617 1401 1491 1286 1128 1010 1034  996 1051  991 1006  905
# ...

# %%
hist
# Out:
# array([  11,   38,  204, 1370,  958,  631,  542,  720, 1115, 1221,  962,
#         849,  823,  736,  666,  624,  628,  567,  593,  552,  575,  556,
#         590,  567,  563,  595,  613,  623,  545,  585,  651,  600,  611,
#         628,  608,  638,  609,  664,  601,  657,  644,  658,  685,  657,
#         741,  775,  800,  841,  834,  796,  806,  788,  714,  708, 1337,
#        3490, 4708, 6134, 6307, 5752, 5196, 6432, 5979, 6659, 5452, 6108,
#        5255, 5485, 5326, 4969, 4379, 4965, 4853, 5197, 4435, 4487, 4831,
#        5069, 4868, 4611, 4699, 4604, 4434, 4649, 4729, 4717, 5149, 4942,
#        4990, 4735, 4543, 4488, 4418, 4340, 4283, 4394, 4590, 5255, 5149,
#        4427, 4135, 4056, 3774, 3801, 3553, 3242, 3465, 3003, 2791, 2653,
#        2725, 2866, 2913, 2662, 2354, 2615, 2577, 2273, 2009, 2231, 2176,
#        2312, 2107, 2029, 1811, 1690, 1626, 1439, 1617, 1401, 1491, 1286,
#        1128, 1010, 1034,  996, 1051,  991, 1006,  905,  914,  940,  965,
# ...

# %%
plt.bar(list(range(256)),hist)
plt.show()

# %% [markdown]
# ### Perform global histogram equalization on result3 and result4, and output the results as result5.pngand result6.png, respectively. Please compare these two resultant images and plot their histograms.

# %% [markdown]
# ### Perform local histogram equalization on result3 and result4, and output the result as result7.pngand result8.png, respectively. Please compare these two resultant images and plot their histograms.
